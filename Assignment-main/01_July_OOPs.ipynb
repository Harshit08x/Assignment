# %%
# This assignment  is submitted by Harshit Agrahari DATE:-20may2024

# 1. What is the primary goal of Object-Oriented Programming (OOP)?

"""
 The primary goal of Object-Oriented Programming (OOP) is to structure software by
breaking it down into smaller, easier-to-manage components called objects. These objects
encapsulate both data and the functions (methods) that operate on that data.

Here are the key goals of OOP: 

1.Robustness:

OOP aims to produce software that is correct and can handle unexpected inputs gracefully.
Robust software should recover from errors and handle well-known limitations of computers.
Correctness and robustness must be designed from the start to avoid embarrassing or life-critical errors1
    
2.Adaptability:

Modern software projects involve large programs expected to last for many years.
OOP allows software to adapt to changing requirements, new features, and evolving user needs.
Components (objects) can be modified, extended, or replaced without affecting the entire system2.

3.Reusability:

OOP promotes code reusability by creating reusable blueprints (classes).
Objects can be instantiated from these classes, allowing developers to reuse existing code.
Reusability reduces development time, minimizes redundancy, and improves maintainability

"""
# Out:
# '\n The primary goal of Object-Oriented Programming (OOP) is to structure software by\nbreaking it down into smaller, easier-to-manage components called objects. These objects\nencapsulate both data and the functions (methods) that operate on that data.\n\nHere are the key goals of OOP: \n\n1.Robustness:\n\nOOP aims to produce software that is correct and can handle unexpected inputs gracefully.\nRobust software should recover from errors and handle well-known limitations of computers.\nCorrectness and robustness must be designed from the start to avoid embarrassing or life-critical errors1\n    \n2.Adaptability:\n\nModern software projects involve large programs expected to last for many years.\nOOP allows software to adapt to changing requirements, new features, and evolving user needs.\nComponents (objects) can be modified, extended, or replaced without affecting the entire system2.\n\n3.Reusability:\n\nOOP promotes code reusability by creating reusable blueprints (classes).\nObje
# ...

# %%
#2. What is an object in Python?

"""
An object is a fundamental concept that represents a real-world entity or a data structure.
Almost everything in Python is an object, and understanding objects is essential for effective programming.

Let’s explore what objects are and how they work:

1.What is an Object?

An object is an instance of a class.

A class serves as a blueprint or template for creating objects.

Objects encapsulate both data (variables) and methods (functions) that operate on that data.

In Python, objects represent real-world entities, such as people, cars, files,
or even abstract concepts like numbers and strings.


2.Key Points about Objects:

Identity: Each object has a unique identity (address in memory).

Type: Objects belong to a specific type (class).

Value: Objects store data (values) associated with their attributes.

Methods: Objects can perform actions through their methods.

3.Creating Objects:

To create an object, we instantiate a class by calling its constructor (usually named __init__).
"""

#Example:

class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

my_car = Car(brand="Toyota", model="Camry")

"""
Here, my_car is an object of the Car class.

Accessing Object Attributes and Methods:

We access object attributes using the dot notation (e.g., my_car.brand).

We invoke object methods similarly (e.g., my_car.start_engine()).

4.Built-in Objects:

Python provides built-in objects (e.g., lists, dictionaries, strings) that are also instances of classes.

These objects have predefined methods and behaviors.

5.Object-Oriented Programming (OOP):

OOP is a programming paradigm that emphasizes objects, classes, and their interactions.

It promotes modularity, reusability, and better code organization.

"""
# Out:
# '\nHere, my_car is an object of the Car class.\n\nAccessing Object Attributes and Methods:\n\nWe access object attributes using the dot notation (e.g., my_car.brand).\n\nWe invoke object methods similarly (e.g., my_car.start_engine()).\n\n4.Built-in Objects:\n\nPython provides built-in objects (e.g., lists, dictionaries, strings) that are also instances of classes.\n\nThese objects have predefined methods and behaviors.\n\n5.Object-Oriented Programming (OOP):\n\nOOP is a programming paradigm that emphasizes objects, classes, and their interactions.\n\nIt promotes modularity, reusability, and better code organization.\n\n'

# %%
#3. What is a class in Python?


"""
A class is a fundamental concept that allows you to create blueprints or templates for creating objects.

1.What is a Class?

A class serves as a template or a structure for creating objects.

It defines a set of attributes (variables) and methods (functions) that the objects created from the class will have.

In other words, a class provides a way to bundle data and functionality together.

2.Creating a Class:

To create a class, use the keyword class."""

#Example:

class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

my_car = Car(brand="Toyota", model="Camry")

"""Here, my_car is an object of the Car class.

3.Attributes and Methods:

Attributes: Represent data associated with the object (e.g., brand, model).

Methods: Define actions or behaviors that the object can perform (e.g., starting the engine).

4.Creating Objects from a Class:

To create an object (instance) from a class, call its constructor (usually named __init__).

Access object attributes using the dot notation (e.g., my_car.brand).

Invoke object methods similarly (e.g., my_car.start_engine()).

"""
# Out:
# 'Here, my_car is an object of the Car class.\n\n3.Attributes and Methods:\n\nAttributes: Represent data associated with the object (e.g., brand, model).\n\nMethods: Define actions or behaviors that the object can perform (e.g., starting the engine).\n\n4.Creating Objects from a Class:\n\nTo create an object (instance) from a class, call its constructor (usually named __init__).\n\nAccess object attributes using the dot notation (e.g., my_car.brand).\n\nInvoke object methods similarly (e.g., my_car.start_engine()).\n\n'

# %%
#4. What are attributes and methods in a class?

"""
1.Attributes:

Attributes represent data associated with an object (instance) of a class.

They define the characteristics or properties of the object.

Attributes are stored as variables within the class.

Examples of attributes include name, age, color, etc.

Access attributes using the dot notation (e.g., my_car.brand).

2.Methods:

Methods define actions or behaviors that an object can perform.

They are functions defined inside a class.

Methods operate on the data (attributes) of the object.

Methods often use the special parameter self to refer to the instance itself.

Examples of methods include start_engine(), calculate_area(), etc.

"""
# Out:
# '\n1.Attributes:\n\nAttributes represent data associated with an object (instance) of a class.\n\nThey define the characteristics or properties of the object.\n\nAttributes are stored as variables within the class.\n\nExamples of attributes include name, age, color, etc.\n\nAccess attributes using the dot notation (e.g., my_car.brand).\n\n2.Methods:\n\nMethods define actions or behaviors that an object can perform.\n\nThey are functions defined inside a class.\n\nMethods operate on the data (attributes) of the object.\n\nMethods often use the special parameter self to refer to the instance itself.\n\nExamples of methods include start_engine(), calculate_area(), etc.\n\n'

# %%
#5. What is the difference between class variables and instance variables in Python?

"""
1.Class Variables:

Class variables are shared among all instances (objects) of a class.

They are declared at the class level (outside any method) using the static keyword (although Python doesn’t explicitly use the static keyword).

Class variables have the same value for all objects of the class.

Changes made to class variables are reflected across all instances.

"""
#Example of class variable

class Car:
    wheels = 4  # Class variable

my_car1 = Car()
my_car2 = Car()

print(my_car1.wheels)  # Output: 4
print(my_car2.wheels)  # Output: 4

Car.wheels = 6  # Update class variable
print(my_car1.wheels)  # Output: 6
print(my_car2.wheels)  # Output: 6

"""
2.Instance Variables:

Instance variables are specific to each individual instance (object) of a class.

They are defined inside the constructor (__init__) and are unique to each object.

Instance variables store data specific to an object’s state.

Changes made to instance variables affect only that particular instance.

"""
#Example of instace variable

class Car:
    def __init__(self, brand):
        self.brand = brand  # Instance variable

my_car1 = Car(brand="Toyota")
my_car2 = Car(brand="Honda")

print(my_car1.brand)  # Output: Toyota
print(my_car2.brand)  # Output: Honda
# Out:
# 4
# 4
# 6
# 6
# Toyota
# Honda

# %%
#6. What is the purpose of the self parameter in Python class methods?
"""
1.self :

When working with classes in Python, the term “self” refers to the instance of the class
that is currently being used.

It is customary to use “self” as the first parameter in instance methods of a class.

Whenever you call a method of an object created from a class, the object is automatically
passed as the first argument using the “self” parameter.

This enables you to modify the object’s properties and execute tasks unique to
that particular instance.

"""
#Example of self parameter
class MyNumber:
    def __init__(self, value):#self you can use any letter instead of self
        self.value = value

    def print_value(self):
        print(self.value)

obj1 = MyNumber(17)
obj1.print_value()  # Output: 17
# Out:
# 17

# %%
""" Question 7. For a library management system, you have to design the "Book" class with OOP
principles in mind.

The “Book” class will have following attributes:

a. title: Represents the title of the book.
b. author: Represents the author(s) of the book.
c. isbn: Represents the ISBN (International Standard Book Number) of the book.
d. publication_year: Represents the year of publication of the book.
e. available_copies: Represents the number of copies available for checkout.

The class will also include the following methods:

a. check_out(self): Decrements the available copies by one if there are copies
available for checkout.
b. return_book(self): Increments the available copies by one when a book is
returned.
c. display_book_info(self): Displays the information about the book, including its
attributes and the number of available copies.
"""
#Answer
class Book:
    def __init__(self, title, author, isbn, publication_year, available_copies):
        """
        Initializes a Book object with the given attributes.

        Args:
            title (str): Title of the book.
            author (str): Author(s) of the book.
            isbn (str): International Standard Book Number.
            publication_year (int): Year of publication.
            available_copies (int): Number of copies available for checkout.
        """
        self.title = title
        self.author = author
        self.isbn = isbn
        self.publication_year = publication_year
        self.available_copies = available_copies

    def check_out(self):
        """
        Decrements the available copies by one if copies are available for checkout.
        """
        if self.available_copies > 0:
            self.available_copies -= 1
            print(f"Book '{self.title}' checked out successfully.")
        else:
            print(f"No available copies of '{self.title}' for checkout.")

    def return_book(self):
        """
        Increments the available copies by one when a book is returned.
        """
        self.available_copies += 1
        print(f"Book '{self.title}' returned. Available copies: {self.available_copies}")

    def display_book_info(self):
        """
        Displays information about the book.
        """
        print(f"Book Information:")
        print(f"Title: {self.title}")
        print(f"Author(s): {self.author}")
        print(f"ISBN: {self.isbn}")
        print(f"Publication Year: {self.publication_year}")
        print(f"Available Copies: {self.available_copies}")


book1 = Book(title="The Great Gatsby", author="F. Scott Fitzgerald", isbn="978-0743273565",
             publication_year=1925, available_copies=5)

book1.check_out()
book1.return_book()
book1.display_book_info()
# Out:
# Book 'The Great Gatsby' checked out successfully.
# Book 'The Great Gatsby' returned. Available copies: 5
# Book Information:
# Title: The Great Gatsby
# Author(s): F. Scott Fitzgerald
# ISBN: 978-0743273565
# Publication Year: 1925
# Available Copies: 5

# %%
"""Question 8. For a ticket booking system, you have to design the "Ticket" class with OOP
principles in mind. The “Ticket” class should have the following attributes:

a. ticket_id: Represents the unique identifier for the ticket.
b. event_name: Represents the name of the event.
c. event_date: Represents the date of the event.
d. venue: Represents the venue of the event.
e. seat_number: Represents the seat number associated with the ticket.
f. price: Represents the price of the ticket.
g. is_reserved: Represents the reservation status of the ticket.

The class also includes the following methods:

a. reserve_ticket(self): Marks the ticket as reserved if it is not already reserved.
b. cancel_reservation(self): Cancels the reservation of the ticket if it is already
reserved.
c. display_ticket_info(self): Displays the information about the ticket, including its
attributes and reservation status."""

#Answer
class Ticket:
    def __init__(self, ticket_id, event_name, event_date, venue, seat_number, price):
        """
        Initializes a Ticket object with the given attributes.

        Args:
            ticket_id (int): Unique identifier for the ticket.
            event_name (str): Name of the event.
            event_date (str): Date of the event (e.g., '2023-05-20').
            venue (str): Venue of the event.
            seat_number (str): Seat number associated with the ticket.
            price (float): Price of the ticket.
        """
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = False  # Initialize as not reserved

    def reserve_ticket(self):
        """
        Marks the ticket as reserved if it is not already reserved.
        """
        if not self.is_reserved:
            self.is_reserved = True
            print(f"Ticket {self.ticket_id} reserved successfully.")
        else:
            print(f"Ticket {self.ticket_id} is already reserved.")

    def cancel_reservation(self):
        """
        Cancels the reservation of the ticket if it is already reserved.
        """
        if self.is_reserved:
            self.is_reserved = False
            print(f"Reservation for ticket {self.ticket_id} canceled.")
        else:
            print(f"Ticket {self.ticket_id} is not reserved.")

    def display_ticket_info(self):
        """
        Displays information about the ticket.
        """
        print(f"Ticket Information:")
        print(f"Ticket ID: {self.ticket_id}")
        print(f"Event Name: {self.event_name}")
        print(f"Event Date: {self.event_date}")
        print(f"Venue: {self.venue}")
        print(f"Seat Number: {self.seat_number}")
        print(f"Price: ${self.price:.2f}")
        print(f"Reservation Status: {'Reserved' if self.is_reserved else 'Not Reserved'}")


ticket1 = Ticket(ticket_id=101, event_name="Concert", event_date="2023-05-20",
                 venue="Music Hall", seat_number="A12", price=50.0)

ticket1.reserve_ticket()
ticket1.display_ticket_info()

ticket1.cancel_reservation()
ticket1.display_ticket_info()
# Out:
# Ticket 101 reserved successfully.
# Ticket Information:
# Ticket ID: 101
# Event Name: Concert
# Event Date: 2023-05-20
# Venue: Music Hall
# Seat Number: A12
# Price: $50.00
# Reservation Status: Reserved
# Reservation for ticket 101 canceled.
# Ticket Information:
# Ticket ID: 101
# Event Name: Concert
# Event Date: 2023-05-20
# Venue: Music Hall
# Seat Number: A12
# Price: $50.00
# Reservation Status: Not Reserved

# %%
""" Question 9. You are creating a shopping cart for an e-commerce website. Using OOP to model
the "ShoppingCart" functionality the class should contain following attributes and
methods:

a. items: Represents the list of items in the shopping cart.

The class also includes the following methods:

a. add_item(self, item): Adds an item to the shopping cart by appending it to the
list of items.
b. remove_item(self, item): Removes an item from the shopping cart if it exists in
the list.
c. view_cart(self): Displays the items currently present in the shopping cart.
d. clear_cart(self): Clears all items from the shopping cart by reassigning an
empty list to the items attribute."""

#Answer
class ShoppingCart:
    def __init__(self):
        """
        Initializes a ShoppingCart object with an empty list of items.
        """
        self.items = []

    def add_item(self, item):
        """
        Adds an item to the shopping cart by appending it to the list of items.

        Args:
            item (str): Item to be added.
        """
        self.items.append(item)
        print(f"Item '{item}' added to the shopping cart.")

    def remove_item(self, item):
        """
        Removes an item from the shopping cart if it exists in the list.

        Args:
            item (str): Item to be removed.
        """
        if item in self.items:
            self.items.remove(item)
            print(f"Item '{item}' removed from the shopping cart.")
        else:
            print(f"Item '{item}' is not in the shopping cart.")

    def view_cart(self):
        """
        Displays the items currently present in the shopping cart.
        """
        if self.items:
            print("Items in the shopping cart:")
            for item in self.items:
                print(f"- {item}")
        else:
            print("The shopping cart is empty.")

    def clear_cart(self):
        """
        Clears all items from the shopping cart by reassigning an empty list to the items attribute.
        """
        self.items = []
        print("Shopping cart cleared.")

cart = ShoppingCart()

cart.add_item("Shirt")
cart.add_item("Jeans")
cart.view_cart()

cart.remove_item("Jeans")
cart.view_cart()

cart.clear_cart()
cart.view_cart()
# Out:
# Item 'Shirt' added to the shopping cart.
# Item 'Jeans' added to the shopping cart.
# Items in the shopping cart:
# - Shirt
# - Jeans
# Item 'Jeans' removed from the shopping cart.
# Items in the shopping cart:
# - Shirt
# Shopping cart cleared.
# The shopping cart is empty.

# %%
"""Question 10. Imagine a school management system. You have to design the "Student" class using
OOP concepts.The “Student” class has the following attributes:
a. name: Represents the name of the student.
b. age: Represents the age of the student.
c. grade: Represents the grade or class of the student.
d. student_id: Represents the unique identifier for the student.
e. attendance: Represents the attendance record of the student.
The class should also include the following methods:
a. update_attendance(self, date, status): Updates the attendance record of the
student for a given date with the provided status (e.g., present or absent).
b. get_attendance(self): Returns the attendance record of the student.
c. get_average_attendance(self): Calculates and returns the average
attendance percentage of the student based on their attendance record."""

#Answer
class Student:
    def __init__(self, name, age, grade, student_id):
        """
        Initializes a Student object with the given attributes.

        Args:
            name (str): Name of the student.
            age (int): Age of the student.
            grade (str): Grade or class of the student.
            student_id (str): Unique identifier for the student.
        """
        self.name = name
        self.age = age
        self.grade = grade
        self.student_id = student_id
        self.attendance = {}  # Initialize an empty dictionary for attendance records

    def update_attendance(self, date, status):
        """
        Updates the attendance record of the student for a given date.

        Args:
            date (str): Date in the format 'YYYY-MM-DD'.
            status (str): Attendance status ('present' or 'absent').
        """
        self.attendance[date] = status

    def get_attendance(self):
        """
        Returns the attendance record of the student.

        Returns:
            dict: A dictionary with date as keys and attendance status as values.
        """
        return self.attendance

    def get_average_attendance(self):
        """
        Calculates and returns the average attendance percentage of the student.

        Returns:
            float: Average attendance percentage.
        """
        total_days = len(self.attendance)
        if total_days == 0:
            return 0.0  # No attendance records available

        present_days = sum(1 for status in self.attendance.values() if status == 'present')
        average_attendance = (present_days / total_days) * 100
        return average_attendance


student1 = Student(name="Alice", age=15, grade="10th", student_id="S12345")
student1.update_attendance(date="2023-05-10", status="present")
student1.update_attendance(date="2023-05-11", status="absent")
student1.update_attendance(date="2023-05-12", status="present")

print(f"{student1.name}'s attendance record:")
print(student1.get_attendance())
print(f"Average attendance: {student1.get_average_attendance():.2f}%")
# Out:
# Alice's attendance record:
# {'2023-05-10': 'present', '2023-05-11': 'absent', '2023-05-12': 'present'}
# Average attendance: 66.67%
